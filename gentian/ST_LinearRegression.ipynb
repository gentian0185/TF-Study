# %%
import tensorflow as tf
import random

#https://ko.wikipedia.org/wiki/%EB%82%9C%EC%88%98
#seed 라 불리는 수를 인자로 매번 다르게 주어 매번 다른 난수를 추출하게끔한다.
#그래서.. 지정하면 같은값이 나와야 하는데 계속 값이 변한다.
tf.set_random_seed(42)


# param
learning_rate = 0.001
training_epochs = 100
batch_size = 20


x_train = [1,2,3]
y_train = [1,2,3]


x_test = [4,5,6]
y_test = [4,5,6]




X = tf.placeholder("float", [3])
Y = tf.placeholder("float", [3])


# 안의 숫자는 shape
i = tf.random_normal([1]);
j = tf.random_normal([1]);
print(i, j)
W = tf.Variable(i, name='weight')
b = tf.Variable(j, name='bias')


# H(x) = Wx + b
hypothesis = x_train * W + b


# cost function
# square : 제곱
# reduce_mean : 평균을 내주는 함수.
cost = tf.reduce_mean(tf.square(hypothesis - y_train))


# Cost minimaze..  0에 가깝도록 변경을 시켜주는 역할.
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
# train : 일종의 노드명
train = optimizer.minimize(cost)


# init session
sess = tf.Session()
# tf.Variable 함수를 사용한 경우에는 반드시 사용해야함.
sess.run(tf.global_variables_initializer())





#start train
for epoch in range(training_epochs):
    total_batch = int(training_epochs/batch_size)
    
    for i in range(total_batch):
        cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict={X:x_train, Y:y_train})
        #cost_val, W_val, _ = sess.run([cost, W, train], feed_dict={X:x_train, Y:y_train})
        # (x) cost_val, W_val, _ = sess.run([cost, W, optimizer], feed_dict={X:x_train, Y:y_train})
        # train 을 안쓴 이유는 인자를 넣을려고..
        # sess.run(train, feed_dict={X:x_train, Y:y_train})
        # sess.run(train)

    print('Epoch:', '%03d' % (epoch + 1), cost_val, W_val, b_val)
    #print('Epoch:', '%03d' % (epoch + 1), sess.run(cost), sess.run(W), sess.run(b))

    
    
print('Learning Finished!')

























# correct prediction test model
#prediction = tf.arg_max(hypothesis, 1)
#is_correct = tf.equal(prediction, tf.arg_max(Y, 1))
# 위 함수는 이것으로 변경될 수 있다.
# correct_prediction = tf.equal(tf.arg_max(hypothesis, 1), tf.arg_max(y_test, 1))
#accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

#print("Prediction:", sess.run(prediction, feed_dict={X: x_test}))
# Calculate the accuracy
#print("Accuracy: ", sess.run(accuracy, feed_dict={X: x_test, Y: y_test}))
# Out:
# Tensor("random_normal_106:0", shape=(1,), dtype=float32) Tensor("random_normal_107:0", shape=(1,), dtype=float32)
# Epoch: 001 0.416525 [ 0.51329535] [ 0.54530978]
# Epoch: 002 0.167493 [ 0.60856813] [ 0.57813632]
# Epoch: 003 0.0897209 [ 0.66294003] [ 0.59307915]
# Epoch: 004 0.0648178 [ 0.69457436] [ 0.59812707]
# Epoch: 005 0.0562502 [ 0.71356094] [ 0.59771734]
# Epoch: 006 0.0527444 [ 0.72550476] [ 0.59431422]
# Epoch: 007 0.0508211 [ 0.73351961] [ 0.58928639]
# Epoch: 008 0.0494061 [ 0.7393356] [ 0.58339351]
# Epoch: 009 0.0481675 [ 0.74391365] [ 0.5770573]
# Epoch: 010 0.0470023 [ 0.74778801] [ 0.57051134]
# Epoch: 011 0.0458786 [ 0.75125539] [ 0.56388509]
# Epoch: 012 0.0447856 [ 0.7544812] [ 0.55724996]
# Epoch: 013 0.04372 [ 0.75755703] [ 0.55064535]
# Epoch: 014 0.0426802 [ 0.76053441] [ 0.54409254]
# Epoch: 015 0.0416651 [ 0.7634418] [ 0.5376029]
# Epoch: 016 0.0406743 [ 0.76629537] [ 0.53118259]
# Epoch: 017 0.039707 [ 0.76910418] [ 0.52483439]
# Epoch: 018 0.0387627 [ 0.77187347] [ 0.51855958]
# Epoch: 071 0.0108248 [ 0.87945175] [ 0.27403456]
# Epoch: 072 0.0105674 [ 0.88089371] [ 0.27075657]
# Epoch: 073 0.0103161 [ 0.8823185] [ 0.26751778]
# Epoch: 074 0.0100708 [ 0.88372618] [ 0.26431772]
# Epoch: 075 0.00983128 [ 0.88511705] [ 0.26115596]
# Epoch: 076 0.00959747 [ 0.88649124] [ 0.25803199]
# Epoch: 077 0.00936924 [ 0.88784903] [ 0.25494543]
# Epoch: 078 0.00914644 [ 0.88919061] [ 0.25189576]
# Epoch: 079 0.00892892 [ 0.8905161] [ 0.24888255]
# Epoch: 080 0.00871659 [ 0.89182574] [ 0.24590541]
# Epoch: 081 0.0085093 [ 0.89311969] [ 0.2429639]
# Epoch: 082 0.00830693 [ 0.89439821] [ 0.24005756]
# Epoch: 083 0.00810939 [ 0.89566147] [ 0.237186]
# Epoch: 084 0.00791654 [ 0.89690959] [ 0.23434879]
# Epoch: 085 0.00772827 [ 0.89814281] [ 0.23154549]
# Epoch: 086 0.00754449 [ 0.89936119] [ 0.22877574]
# Epoch: 087 0.00736507 [ 0.90056503] [ 0.22603911]
# Epoch: 088 0.00718993 [ 0.90175444] [ 0.22333522]
# Epoch: 089 0.00701894 [ 0.9029296] [ 0.2206637]
# Epoch: 090 0.00685202 [ 0.90409076] [ 0.21802412]
# Epoch: 091 0.00668908 [ 0.90523803] [ 0.21541612]
# Epoch: 092 0.00653002 [ 0.90637159] [ 0.21283932]
# Epoch: 093 0.00637471 [ 0.90749156] [ 0.21029335]
# Epoch: 094 0.00622313 [ 0.90859812] [ 0.20777784]
# Epoch: 095 0.00607513 [ 0.90969151] [ 0.20529239]
# Epoch: 096 0.00593066 [ 0.91077179] [ 0.20283666]
# Epoch: 097 0.00578963 [ 0.91183913] [ 0.20041034]
# Epoch: 098 0.00565194 [ 0.91289377] [ 0.19801304]
# Epoch: 099 0.00551753 [ 0.91393572] [ 0.19564438]
# Epoch: 100 0.00538632 [ 0.91496521] [ 0.19330409]
# Learning Finished!
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#
# C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#
# C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: Expected dimension in the range [-1, 1), but got 1
# 	 [[Node: ArgMax_17 = ArgMax[T=DT_FLOAT, Tidx=DT_INT32, output_type=DT_INT64, _device="/job:localhost/replica:0/task:0/device:CPU:0"](add_47, ArgMax_17/dimension)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-69-895c09a5211b> in <module>()
#      89 accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
#      90
# ---> 91 print("Prediction:", sess.run(prediction, feed_dict={X: x_test}))
#      92 # Calculate the accuracy
#      93 print("Accuracy: ", sess.run(accuracy, feed_dict={X: x_test, Y: y_test}))
#
# C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1361         except KeyError:
#    1362           pass
# -> 1363       raise type(e)(node_def, op, message)
#    1364
#    1365   def _extend_graph(self):
#
# InvalidArgumentError: Expected dimension in the range [-1, 1), but got 1
# 	 [[Node: ArgMax_17 = ArgMax[T=DT_FLOAT, Tidx=DT_INT32, output_type=DT_INT64, _device="/job:localhost/replica:0/task:0/device:CPU:0"](add_47, ArgMax_17/dimension)]]
#
# Caused by op 'ArgMax_17', defined at:
#   File "C:\nanum\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\nanum\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\nanum\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\nanum\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\nanum\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\nanum\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\nanum\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\nanum\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\nanum\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\nanum\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\nanum\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\nanum\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\nanum\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\nanum\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\nanum\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\nanum\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\nanum\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\nanum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\nanum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\nanum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-69-895c09a5211b>", line 85, in <module>
#     prediction = tf.arg_max(hypothesis, 1)
#   File "C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 136, in new_func
#     return func(*args, **kwargs)
#   File "C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 508, in arg_max
#     name=name)
#   File "C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "C:\nanum\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Expected dimension in the range [-1, 1), but got 1
# 	 [[Node: ArgMax_17 = ArgMax[T=DT_FLOAT, Tidx=DT_INT32, output_type=DT_INT64, _device="/job:localhost/replica:0/task:0/device:CPU:0"](add_47, ArgMax_17/dimension)]]
